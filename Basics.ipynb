# %% [markdown]
# # Jeopardy  (TV show) questions

# %%
import pandas as pd
import numpy as np
jeopardy = pd.read_csv('jeopardy.csv')

# %%
jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
# removes blanks in front of each column name
jeopardy.columns.str.strip()
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
jeopardy.rename(dict(zip(jeopardy.columns, jeopardy.columns.str.strip())), axis=1, inplace=True)

# %%
jeopardy.columns
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
# normalize questions and answers, first checkout the original questions and answers
print(jeopardy['Question'][0])
print(jeopardy['Answer'][0])
# Out:
# For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# Copernicus

# %%
# define a function to edit the text strings and apply on Question and Answer columns
import string
def clean_str(str):
    str_lower = str.lower()
    for c in string.punctuation:
        str_lower = str_lower.replace(c, '')
    return str_lower

# %%
jeopardy['clean_question'] = jeopardy['Question'].apply(clean_str)

# %%
jeopardy['clean_question'][0]
# Out:
# 'for the last 8 years of his life galileo was under house arrest for espousing this mans theory'

# %%
jeopardy['clean_answer'] = jeopardy['Answer'].apply(clean_str)
print(jeopardy['clean_answer'][0])
# Out:
# copernicus

# %%
jeopardy.head(3)
# Out:
#    Show Number    Air Date      Round                         Category Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
#
#                                             Question      Answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
#
#                                       clean_question clean_answer
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona

# %%
## normalize value column by removing the $ sign
jeopardy['Value'].unique()
# Out:
# array(['$200', '$400', '$600', '$800', '$2,000', '$1000', '$1200',
#        '$1600', '$2000', '$3,200', 'None', '$5,000', '$100', '$300',
#        '$500', '$1,000', '$1,500', '$1,200', '$4,800', '$1,800', '$1,100',
#        '$2,200', '$3,400', '$3,000', '$4,000', '$1,600', '$6,800',
#        '$1,900', '$3,100', '$700', '$1,400', '$2,800', '$8,000', '$6,000',
#        '$2,400', '$12,000', '$3,800', '$2,500', '$6,200', '$10,000',
#        '$7,000', '$1,492', '$7,400', '$1,300', '$7,200', '$2,600',
#        '$3,300', '$5,400', '$4,500', '$2,100', '$900', '$3,600', '$2,127',
#        '$367', '$4,400', '$3,500', '$2,900', '$3,900', '$4,100', '$4,600',
#        '$10,800', '$2,300', '$5,600', '$1,111', '$8,200', '$5,800',
#        '$750', '$7,500', '$1,700', '$9,000', '$6,100', '$1,020', '$4,700',
#        '$2,021', '$5,200', '$3,389'], dtype=object)

# %%
def clean_val(inp):
    inp_nopunc = inp
    try:
        for c in string.punctuation:
            inp_nopunc = inp_nopunc.replace(c, '')
        return int(inp_nopunc)
    except Exception:
        return 0

# %%
jeopardy['clean_value'] = jeopardy['Value'].apply(clean_val)

# %%
jeopardy['clean_value'].unique()
# Out:
# array([  200,   400,   600,   800,  2000,  1000,  1200,  1600,  3200,
#            0,  5000,   100,   300,   500,  1500,  4800,  1800,  1100,
#         2200,  3400,  3000,  4000,  6800,  1900,  3100,   700,  1400,
#         2800,  8000,  6000,  2400, 12000,  3800,  2500,  6200, 10000,
#         7000,  1492,  7400,  1300,  7200,  2600,  3300,  5400,  4500,
#         2100,   900,  3600,  2127,   367,  4400,  3500,  2900,  3900,
#         4100,  4600, 10800,  2300,  5600,  1111,  8200,  5800,   750,
#         7500,  1700,  9000,  6100,  1020,  4700,  2021,  5200,  3389])

# %%
jeopardy['Air Date']
# Out:
# 0        2004-12-31
# 1        2004-12-31
# 2        2004-12-31
# 3        2004-12-31
# 4        2004-12-31
# 5        2004-12-31
# 6        2004-12-31
# 7        2004-12-31
# 8        2004-12-31
# 9        2004-12-31
# 10       2004-12-31
# 11       2004-12-31
# 12       2004-12-31
# 13       2004-12-31
# 14       2004-12-31
# 15       2004-12-31
# 16       2004-12-31
# 17       2004-12-31
# 18       2004-12-31
# 19       2004-12-31
# 20       2004-12-31
# 21       2004-12-31
# 22       2004-12-31
# 23       2004-12-31
# 24       2004-12-31
# 25       2004-12-31
# 26       2004-12-31
# 27       2004-12-31
# 28       2004-12-31
# 29       2004-12-31
#             ...
# 19969    2009-05-14
# 19970    2009-05-14
# 19971    2009-05-14
# 19972    2009-05-14
# 19973    2009-05-14
# 19974    2009-05-14
# 19975    2009-05-14
# 19976    2009-05-14
# 19977    2009-05-14
# 19978    2009-05-14
# 19979    2009-05-14
# 19980    2009-05-14
# 19981    2009-05-14
# 19982    2009-05-14
# 19983    2009-05-14
# 19984    2009-05-14
# 19985    2009-05-14
# 19986    2009-05-14
# 19987    2009-05-14
# 19988    2000-03-14
# 19989    2000-03-14
# 19990    2000-03-14
# 19991    2000-03-14
# 19992    2000-03-14
# 19993    2000-03-14
# 19994    2000-03-14
# 19995    2000-03-14
# 19996    2000-03-14
# 19997    2000-03-14
# 19998    2000-03-14
# Name: Air Date, Length: 19999, dtype: object

# %%
# convert air date to a datetime column
jeopardy['date'] = pd.to_datetime(jeopardy['Air Date'])

# %%
jeopardy_clean = jeopardy.copy().drop(['Air Date', 'Value','Question','Answer'],axis=1)

# %%
jeopardy_clean.head()
# Out:
#    Show Number      Round                         Category  \
# 0         4680  Jeopardy!                          HISTORY
# 1         4680  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES
# 2         4680  Jeopardy!      EVERYBODY TALKS ABOUT IT...
# 3         4680  Jeopardy!                 THE COMPANY LINE
# 4         4680  Jeopardy!              EPITAPHS & TRIBUTES
#
#                                       clean_question clean_answer  \
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona
# 3  in 1963 live on the art linkletter show this c...    mcdonalds
# 4  signer of the dec of indep framer of the const...   john adams
#
#    clean_value       date
# 0          200 2004-12-31
# 1          200 2004-12-31
# 2          200 2004-12-31
# 3          200 2004-12-31
# 4          200 2004-12-31

# %% [markdown]
# ### We have cleaned the data and saved it to another DataFrame jeopardy_clean

# %% [markdown]
# ## How often the answer is deducible from the question, i.e. the answer is already in the question?

# %%
# define a function that calculates how many times each word in answer occurs in question
def count_answer_in_question(row):
    split_answer = row['clean_answer'].split(' ')
    split_question = row['clean_question'].split(' ')
    match_count = 0
    if 'the' in split_answer:
        split_answer.remove('the')
    if len(split_answer) == 0:
        return 0
    else:
        for word in split_answer:
            if word in split_question:
                match_count += 1
        return match_count /len(split_answer)

# %%
count_answer_in_question(jeopardy_clean.loc[0])
# Out:
# 0.0

# %%
jeopardy_clean['answer_in_question'] = jeopardy_clean.apply(count_answer_in_question, axis=1)

# %%
print(jeopardy_clean['answer_in_question'].mean())
print(jeopardy_clean['answer_in_question'].median())
# Out:
# 0.06035277385469894
# 0.0

# %% [markdown]
# ### Although typically the answer is not in the question (median count = 0), the average count of answer appearing in question is 0.06

# %% [markdown]
# ## How many questions are repeated from old question? Find the key words of each question and count the occurrance.

# %%
question_overlap = []
terms_used = set()
for index, row in jeopardy_clean.iterrows():
    split_question = row['clean_question'].split(' ')
    for word in split_question:
        if len(word) < 6:
            split_question.remove(word)
    match_count = 0
    for word in split_question:
        if word in terms_used:
            match_count += 1
        terms_used.add(word)
    if len(split_question) > 0:
#        print(row)
        question_overlap.append(match_count/len(split_question))
    else:
        question_overlap.append(0)

jeopardy_clean['question_overlap']  = question_overlap
print(jeopardy_clean['question_overlap'].mean())
# Out:
# 0.8035657890528735

# %% [markdown]
# ### The rate of repeating questions is quite high.

# %% [markdown]
# ## Focus on high-value questions

# %%
def high_val(row):
    if row['clean_value'] > 800:
        value = 1
    else:
        value = 0
    return value
jeopardy_clean['high_value'] = jeopardy_clean.apply(high_val, axis=1)

# %%
def high_low(word):
    low_count = 0
    high_count = 0
    for index, row in jeopardy_clean.iterrows():
        split_question = row['clean_question'].split(' ')
        if word in split_question:
            if row['high_value'] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count

# %%
comparison_terms = list(terms_used)

# %%
comparison_terms.remove('')

# %%
comparison_terms[:5]
# Out:
# ['seltzer',
#  'threepenny',
#  'pa',
#  'continue',
#  'nairobi',
#  'unknowns',
#  'hungary',
#  'quindlen',
#  'ecological',
#  'presbyterian',
#  'einheriar',
#  'amar',
#  '4inch',
#  'wolfhound',
#  'annuus',
#  'budd',
#  'winkies',
#  'afghanistan',
#  'lydians',
#  'lords',
#  'ebenezer',
#  'plaza',
#  'had',
#  'jersey',
#  'hrefhttpwwwjarchivecommedia20070719dj02ajpg',
#  'final',
#  'dillon',
#  'kettles',
#  'delite',
#  'operators',
#  'smelter',
#  'aureum',
#  'irrigated',
#  '1815',
#  'charlaine',
#  'childlike',
#  'costar',
#  'hearing',
#  'everywhere',
#  'nursery',
#  'oscarsa',
#  'neigh',
#  'norwest',
#  'harrys',
#  'galilee',
#  'jerzy',
#  'single',
#  'sewards',
#  'specifically',
#  'lookst',
#  'maid',
#  'speciale',
#  'struggle',
#  'front',
#  'khrushchev',
#  'morial',
#  'vertebral',
#  'oesterreich',
#  'waterpower',
#  'reordering',
#  'krakauer',
#  'macdui',
#  'thisand',
#  'these',
#  'pajama',
#  'spellings',
#  'hollyhock',
#  'amherst',
#  'drilling',
#  'ross',
#  'strangers',
#  'professionals',
#  'chinos',
#  'lowtemperature',
#  'addams',
#  'spouse',
#  'buddy',
#  'wide',
#  'walla',
#  'mancini',
#  'targetblankhi',
#  'freezes',
#  'won',
#  'oberon',
#  'allmale',
#  'rollins',
#  'kirkendall',
#  'circulate',
#  'comrades',
#  'murray',
#  'transplant',
#  'hrefhttpwwwjarchivecommedia20050502j01jpg',
#  'bullseye',
#  'tackle',
#  'pull',
#  'lowi',
#  'cesta',
#  'wiarton',
#  '1513',
#  'yellowbrown',
#  'abstaining',
#  'extracted',
#  'multitudinous',
#  'lucrezia',
#  'bitterroot',
#  'forger',
#  'repertory',
#  'architecturally',
#  'targetblanklunch',
#  'specializing',
#  'hanson',
#  'folds',
#  'teased',
#  '2block',
#  'mets',
#  'lillian',
#  'devises',
#  'tennessee',
#  'pirates',
#  'cincy',
#  'aerosmith',
#  '450foot',
#  'neutrons',
#  'schooner',
#  '900000',
#  'viking',
#  'aspects',
#  'lather',
#  'uniting',
#  'engineer',
#  'glasssteagall',
#  'emmeline',
#  'cruciform',
#  'buddhism',
#  'plantagenet',
#  'stillman',
#  'nikolay',
#  'swimmer',
#  'payloads',
#  'thakura',
#  'requesting',
#  'canisters',
#  'encore',
#  'defender',
#  'lane',
#  'recovered',
#  'ragged',
#  'thames',
#  '1928',
#  'charming',
#  'krusty',
#  'talkin',
#  'sculptor',
#  'resignation',
#  'hrefhttpwwwjarchivecommedia20080227dj27jpg',
#  'tattooed',
#  'csection',
#  'fabric',
#  '1894',
#  'macchios',
#  'ugandan',
#  'ethan',
#  'persistent',
#  'httpwwwjarchivecomread',
#  'odoriferous',
#  'humphry',
#  'purity',
#  'osmond',
#  'iimited',
#  'fantasie',
#  'ichiro',
#  'daniels',
#  'shoesa',
#  'warmer',
#  'candle',
#  'literal',
#  'caldarium',
#  'awards',
#  'sniffling',
#  'sabah',
#  'targetblankmena',
#  'romanced',
#  'bagging',
#  'within',
#  'freys',
#  'geneticists',
#  'candidates',
#  'handkerchief',
#  'entsor',
#  'employment',
#  'nh',
#  'dubner',
#  'nationalists',
#  'nepals',
#  'showed',
#  'grounda',
#  'crunk',
#  'zion',
#  'sabbath',
#  'curve',
#  'delineated',
#  'kenyas',
#  'zurich',
#  'pavilion',
#  'harakiri',
#  'griesea',
#  'prayed',
#  'ellipses',
#  'knowses',
#  'banquet',
#  'g',
#  'inventors',
#  'scoundrels',
#  'slogans',
#  'includes',
#  'famine',
#  'hrefhttpwwwjarchivecommedia20100528dj02jpg',
#  'tenant',
#  'sallied',
#  'drag',
#  'inherits',
#  'media”',
#  'hrefhttpwwwjarchivecommedia20091014j08jpg',
#  'droppeth',
#  'kelley',
#  'ediths',
#  'antonio',
#  'pipelines',
#  'lignite',
#  'fought',
#  'targetblanknailsa',
#  'khaury',
#  'kol',
#  'soprano',
#  'perfumers',
#  'psi',
#  'houses',
#  'gaslight',
#  'meats',
#  'ellen',
#  'ouroboros',
#  'morehead',
#  'counsel',
#  'unconquerable',
#  'flavor',
#  'generator',
#  'il',
#  'teller',
#  'margarita',
#  'olivier',
#  'nazi',
#  'courtesan',
#  'pennys',
#  'wavy',
#  'taras',
#  'brabant',
#  'friedland',
#  'helena',
#  'operettas',
#  'bioinsecticides',
#  'janes',
#  'saves',
#  'baseball',
#  'junker',
#  'voices',
#  '50year',
#  'hargreaves',
#  'athos',
#  'iceland',
#  'jennifer',
#  'manzanilla',
#  'junta',
#  'setupa',
#  'provisions',
#  '16yearold',
#  'hrefhttpwwwjarchivecommedia20060516dj22wmvilove',
#  'manchesters',
#  'minneapolis',
#  'kissing',
#  'subterranean',
#  'crypt',
#  'hipparchus',
#  'mel',
#  'squaredoff',
#  'selfreliance',
#  'loan',
#  'nijinsky',
#  'muppets',
#  'moons',
#  'fingershaped',
#  'swarthout',
#  'burner',
#  'bonded',
#  'reply',
#  'sail',
#  'beagles',
#  '1877',
#  'galaxys',
#  'autant',
#  'presented',
#  'mindstorms',
#  'astrophysicists',
#  'mcbride',
#  'steven',
#  '212foot',
#  'christiania',
#  'stellar',
#  'agreed',
#  'zappafrank',
#  'hernando',
#  'clansman',
#  'lecturer',
#  'champs',
#  'notably',
#  'plated',
#  'pledged',
#  'appetite',
#  'netlike',
#  'last',
#  'backed',
#  'badbreathbusting',
#  'petal',
#  'zuni',
#  'deer',
#  'book',
#  'robby',
#  'wherever',
#  'hrefhttpwwwjarchivecommedia20091002dj02ajpg',
#  'microclimates',
#  'zero',
#  'melbourne',
#  'hsx',
#  'devices',
#  'targetblanknew',
#  'cocktails',
#  'entertain',
#  'pense',
#  'targetblank',
#  'sisters',
#  'souvlak',
#  'mil',
#  'leonard',
#  '311',
#  'ride',
#  'rebounds',
#  'consultant',
#  'plymouth',
#  '12yardlong',
#  'theatres',
#  'realm',
#  'aleichems',
#  'tans',
#  'redskins',
#  'hrefhttpwwwjarchivecommedia20070219j04jpg',
#  'nonflowering',
#  'indicates',
#  'groupie',
#  'revival',
#  'weimar',
#  'handwriting',
#  'milwaukees',
#  'shewolf',
#  'widebrimmed',
#  'activist',
#  'alias',
#  'aircraft',
#  'badly',
#  'hairier',
#  'expressed',
#  'malady',
#  'unfavorable',
#  'whining',
#  'greenmeldrim',
#  'threatens',
#  'biographical',
#  'rockrap',
#  'bowlers',
#  'h',
#  'alpha',
#  'patricia',
#  'noticing',
#  'disinfectant',
#  'heirs',
#  'estuary',
#  'mans',
#  'promptly',
#  'catalonia',
#  'wilderness',
#  'erected',
#  'rome',
#  'galbraith',
#  'bombie',
#  'wilders',
#  'thimblefinger',
#  'potts',
#  'faceout',
#  'por',
#  'dartagnan',
#  'madeline',
#  'saladin',
#  'horseradish',
#  'lerner',
#  'pledges',
#  'sarawak',
#  'godspeed',
#  'discoveryland',
#  'chops',
#  'snowboards',
#  'restorating',
#  'claire',
#  'fantasque',
#  'marionettes',
#  'automatons',
#  'songwriter',
#  'einstein',
#  'decidedly',
#  'hrefhttpwwwjarchivecommedia20070330j14jpg',
#  'bosnian',
#  'gahagan',
#  'angular',
#  'mulberry',
#  '250000',
#  'bollywood',
#  'polished',
#  'hrefhttpwwwjarchivecommedia20110713j07jpg',
#  'est',
#  'allworthy',
#  'hrefhttpwwwjarchivecommedia20090211dj11ajpg',
#  'inn',
#  'neptunes',
#  'fingertip',
#  'pickering',
#  'freddys',
#  'tim',
#  'mondavi',
#  'stadsholmen',
#  'schuyler',
#  'memphis',
#  '25yearold',
#  'quite',
#  'occasion',
#  'firearms',
#  'transform',
#  'insubordination',
#  'electrons',
#  'petticoats',
#  'declaring',
#  'olympia',
#  'targetblankpresidenta',
#  'distinguished',
#  'copacabana',
#  'sopranos',
#  'acknowledgement',
#  'kirk',
#  'layzie',
#  'rom',
#  'carriage',
#  'yellow',
#  'stalin',
#  'suez',
#  'brennan',
#  'watera',
#  'volcanos',
#  'wisteria',
#  'properties',
#  'quayle',
#  'piggywig',
#  'gregorian',
#  'catoche',
#  'mssundaztood',
#  'sunk',
#  'inclined',
#  'karras',
#  '907',
#  'calculators',
#  'staying',
#  'dubai',
#  'beheading',
#  'appropriatesounding',
#  'offspring',
#  'grandsons',
#  'hrefhttpwwwjarchivecommedia20001003dj05bjpg',
#  'loaf',
#  'contributing',
#  'watch',
#  'carpenter',
#  'parmigiana',
#  'batting',
#  'dethroned',
#  'spaghetti',
#  'womans',
#  'oralando',
#  'satire',
#  'spoof',
#  'hrefhttpwwwjarchivecommedia20090327dj26jpg',
#  'offer',
#  'masterson',
#  'viewers',
#  'flagpoles',
#  'protected',
#  'whopper',
#  'billings',
#  'anagnostopoulos',
#  'marrakesh',
#  'spectacled',
#  'leg',
#  'leblanc',
#  'under',
#  'psychiatric',
#  'skookum',
#  'saintexupery',
#  'communist',
#  'tatars',
#  'janitors',
#  'leslies',
#  'christabel',
#  'interrelation',
#  'chopin',
#  'hear',
#  'smeaton',
#  'flamborough',
#  'baskinrobbins',
#  'voiced',
#  'hookes',
#  'kingsley',
#  'muffet',
#  'colleague',
#  'tilneys',
#  'raleigh',
#  'phoebe',
#  'grille',
#  'pleasant',
#  'attacked',
#  'vivaldi',
#  'alumna',
#  'hapsburgs',
#  'relatively',
#  'feather',
#  'mountbattens',
#  'rovers',
#  'archrival',
#  'tasman',
#  'plaintive',
#  'licked',
#  'scheherazades',
#  'carmack',
#  'tidings',
#  'hrefhttpwwwjarchivecommedia19980225j25bjpg',
#  'stink',
#  'update',
#  'visigoths',
#  'oui',
#  'shiloh',
#  'invention',
#  '6yearold',
#  'nectarine',
#  'mulvaneys',
#  'hrefhttpwwwjarchivecommedia20060725j01mp3thisa',
#  'rice',
#  'vibrissae',
#  'incurs',
#  'hrefhttpwwwjarchivecommedia20070530j27jpg',
#  'remonstrance',
#  'hussein',
#  '6th',
#  'erosion',
#  'disk',
#  'dupe',
#  'erickson',
#  'rural',
#  'hrefhttpwwwjarchivecommedia20101104dj28jpg',
#  'crop',
#  'dearborn',
#  'renoir',
#  'respects',
#  'notebook',
#  '3040',
#  'dunant',
#  'salukis',
#  'rid',
#  'marker',
#  'gevalt',
#  'crypts',
#  'hamnett',
#  'daly',
#  'aoibhinn',
#  'annexed',
#  'toobin',
#  'publish',
#  'shakespearean',
#  'tabasco',
#  'window',
#  'hollowedout',
#  'results',
#  '30s',
#  'hrefhttpwwwjarchivecommedia20070124j15jpg',
#  'davis',
#  'newshour',
#  'skysoaring',
#  'swallow',
#  'earliest',
#  '1566',
#  'methods',
#  'hrefhttpwwwjarchivecommedia20060425dj15jpg',
#  'tahiti',
#  'trials',
#  'viewed',
#  'projectiles',
#  'shocking',
#  'baretta',
#  'fluted',
#  'emptying',
#  'staffed',
#  'franklins',
#  'buds',
#  'breathe',
#  'browning',
#  'spade',
#  'regional',
#  'xingjian',
#  'conversation',
#  'hills',
#  'crushing',
#  'schizophrenic',
#  'washingtons',
#  'fillmore',
#  'imaginary',
#  'bloodsucking',
#  'dentiform',
#  'plugged',
#  'towering',
#  'hour',
#  'millionaire',
#  'inhabited',
#  'bernanke',
#  'rights',
#  'hobbit',
#  'modernqueen',
#  'potable',
#  'redstalked',
#  'hostility',
#  'monarchs',
#  'owners',
#  'executive',
#  'park',
#  'monks',
#  'restaurants',
#  'gantry',
#  '1420s',
#  'rick',
#  'eminem',
#  'silversmith',
#  'tu',
#  'rigatoni',
#  'oilrich',
#  'rightwing',
#  '1990s',
#  'previn',
#  'bestpaid',
#  'myerson',
#  'checkout',
#  'beauharnais',
#  'warriors',
#  'gleans',
#  'subspecies',
#  'soaked',
#  'radish',
#  'upwardly',
#  'enfants',
#  'tonkin',
#  'minoans',
#  'emitted',
#  'roving',
#  'seamus',
#  'dreamy',
#  'chigoe',
#  'plo',
#  'struensee',
#  'ortografia',
#  '3rd',
#  'elephterian',
#  'omnipotence',
#  'canine',
#  'attempted',
#  'lodine',
#  'theatersand',
#  'brunei',
#  'moves',
#  '1704',
#  'bidens',
#  '221b',
#  'eschewed',
#  'limp',
#  'sneaking',
#  'divide',
#  'duomo',
#  'kelvin',
#  'ruth',
#  'panamanian',
#  'montoya',
#  'simply',
#  'spells',
#  'journalist',
#  'enamel',
#  'targetblankcharles',
#  'kisses',
#  'hrefhttpwwwjarchivecommedia20071226dj16jpg',
#  'headless',
#  'veneto',
#  'rewrites',
#  '1938',
#  'trumpet',
#  'paid',
#  'rebellion',
#  'token',
#  'cranapples',
#  'ushers',
#  'i',
#  'houdon',
#  'bon',
#  'celesteville',
#  'injera',
#  'langley',
#  'mongolian',
#  'correspondant',
#  '1968',
#  'hrefhttpwwwjarchivecommedia20050315j02jpg',
#  'whistlers',
#  'street',
#  'capabilities',
#  'lee',
#  'disgrace',
#  'waysfor',
#  'six',
#  'punch',
#  '1685',
#  'rosaceae',
#  'supplied',
#  'triskaidekaphobic',
#  'brim',
#  '1220',
#  'snowy',
#  'dickens',
#  'tot',
#  'diaries',
#  'nikes',
#  'mca',
#  '8820',
#  'earnest',
#  'google',
#  'induces',
#  'savoycarignano',
#  'jailed',
#  'targetblanksheas',
#  'fatburger',
#  'happening',
#  'onboard',
#  'sloping',
#  'confusing',
#  'daring',
#  'indents',
#  'thisdried',
#  'purification',
#  'tutti',
#  'nostalgia',
#  'archaeological',
#  'allusion',
#  'mentha',
#  'mcclellans',
#  'mariah',
#  'folk',
#  'pia',
#  'taft',
#  'drownings',
#  'dressage',
#  'dispatch',
#  'thrilling',
#  'carville',
#  'duos',
#  'savage',
#  'tyranny',
#  'gallows',
#  'charts',
#  'halite',
#  'valery',
#  'englands',
#  'hrefhttpwwwjarchivecommedia20050411j29jpg',
#  'julian',
#  'mojave',
#  'smoothsinging',
#  'dwellers',
#  'ferris',
#  'states',
#  'defamed',
#  'deepfried',
#  '1932',
#  'mozambique',
#  'haddon',
#  'croquet',
#  'nkrumah',
#  'jorgesmy',
#  'tagish',
#  'edgy',
#  'windy',
#  'eller',
#  'ursine',
#  'companies',
#  'kinetix',
#  '1816',
#  'outing',
#  'zandonai',
#  'force',
#  'buyers',
#  'countess',
#  'hrefhttpwwwjarchivecommedia20100101j29wmvsarah',
#  'melanoleuca',
#  'toobins',
#  'pyrotechnics',
#  'throats',
#  '65000',
#  'collected',
#  'milelong',
#  'joel',
#  'chafing',
#  'mercutio',
#  'heading',
#  'approval',
#  'masteratarms',
#  'macready',
#  'clumsy',
#  'rooms',
#  'angstroms',
#  'salma',
#  'yu',
#  'blinkor',
#  '1819',
#  'futuristic',
#  'hitchhike',
#  'particle',
#  'octopusflavored',
#  'vegetables',
#  'newsmaking',
#  'montmartre',
#  'solanaceae',
#  'enlightenment',
#  'stimpy',
#  'yaroslavna',
#  'cadpig',
#  'ultraorthodox',
#  'relates',
#  'kick',
#  'peoples',
#  'coasts',
#  'theotokopoulos',
#  'import',
#  'hinged',
#  'hrefhttpwwwjarchivecommedia20111024j27jpg',
#  'maori',
#  'stitches',
#  'me',
#  'hirudinea',
#  'minuets',
#  '1650',
#  'highgrade',
#  'societies',
#  'eyelashes',
#  'boomerang',
#  'bierstadt',
#  'apostles',
#  '2009s',
#  'pons',
#  'orginated',
#  'hrefhttpwwwjarchivecommedia20040706j09wmvthe',
#  'horns',
#  'dantes',
#  'cullen',
#  'scaling',
#  'bicentennial',
#  'coconuts',
#  'targetblankmurala',
#  'achaemenid',
#  'unaccompanied',
#  'anterior',
#  'waterside',
#  'lawyers',
#  'yshaped',
#  'cream',
#  'prizea',
#  'indulge',
#  'tricks',
#  '1904',
#  '1673',
#  'ferguson',
#  'pericles',
#  'manatees',
#  'royal',
#  'spanishnamed',
#  'platinum',
#  'sept',
#  'spender',
#  '323',
#  'fleurs',
#  'fate',
#  'arsenic',
#  'lakefront',
#  'mahimahi',
#  'privileges',
#  'successful',
#  'bradham',
#  'ismael',
#  'agony',
#  'porky',
#  'lassen',
#  'errol',
#  'dedicating',
#  'ogemaw',
#  'talons',
#  'ark',
#  'hrefhttpwwwjarchivecommedia20091117j12jpg',
#  'kiddieseverything',
#  'trident',
#  'flashy',
#  'functionso',
#  'weave',
#  'horn',
#  'danced',
#  'filling',
#  'bertha',
#  'thelonious',
#  'dot',
#  'pikes',
#  'ths',
#  'spotting',
#  'manassa',
#  'cornish',
#  'isthmus',
#  'reddi',
#  'responsible',
#  'trusteeship',
#  'schnitzel',
#  'bisbee',
#  'gangster',
#  'hunsicker',
#  'staging',
#  'unrebuilt',
#  'andras',
#  'sundried',
#  'battlesome',
#  'quelle',
#  'trilobites',
#  'mannix',
#  'desk',
#  'vewy',
#  'fares',
#  'sid',
#  'charlize',
#  'lining',
#  'dave',
#  'sciencefiction',
#  'screensaver',
#  'firecracker',
#  'tagline',
#  'faces',
#  'absorbent',
#  'ozone',
#  'stephen',
#  'stretch',
#  'remember',
#  'hike',
#  'gaza',
#  'epa',
#  '1997s',
#  'soothsayer',
#  'terrestrial',
#  'cygnus',
#  'deaf',
#  '1962',
#  'senses',
#  'yearns',
#  'starfall',
#  'meegeren',
#  'gaiety',
#  'entranceway',
#  'fullfigured',
#  'project',
#  'lodestone',
#  'refrigerated',
#  'thornfield',
#  'worshiper',
#  'niven',
#  'mermaid',
#  'metabolic',
#  'crossfield',
#  'iv',
#  'columnist',
#  'argos',
#  'prance',
#  'villains',
#  'guillotined',
#  'ore',
#  ...]

# %%
observed_expected = []
for word in comparison_terms[:5]:
    observed_expected.append(high_low(word))

# %%
observed_expected
# Out:
# [(0, 1), (1, 0), (2, 4), (0, 2), (1, 3)]

# %%
high_value_count = jeopardy_clean[jeopardy_clean['high_value']==1].shape[0]
low_value_count = jeopardy_clean[jeopardy_clean['high_value']==0].shape[0]

# %%
chi_squared = []
from scipy.stats import chisquare
#from scipy.stats import chi2_contigency

for ls in observed_expected:
    total = np.sum(ls)
    total_prop = total / jeopardy_clean.shape[0]
    high_exp = high_value_count * total_prop
    low_exp = low_value_count * total_prop

    chi_squared.append(chisquare(ls, [high_exp, low_exp]))

# %%
chi_squared
# Out:
# [Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=0.06376233446880725, pvalue=0.8006453026878781),
#  Power_divergenceResult(statistic=0.803925692253768, pvalue=0.3699222378079571),
#  Power_divergenceResult(statistic=0.02636443308440769, pvalue=0.871013484688921)]

# %% [markdown]
# ### The first 5 terms have big p values, meaning their reoccurrances are statistically insignificant.
